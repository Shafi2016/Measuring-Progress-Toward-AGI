# %%
from pathlib import Path

folder = Path(r"C:\Users\shafiullah.qureshi\OneDrive - Government of Alberta\Documents\unit_work\shafi_docs\Kaggle_agi\Q3_updated\results_q3_attention_upgraded_M7\epu_attention_q3_upgraded_outputs")

for file_path in folder.iterdir():
    if file_path.is_file() and not file_path.name.startswith("gpt_5.4_"):
        new_name = "gpt_5.4_" + file_path.name
        new_path = file_path.with_name(new_name)
        file_path.rename(new_path)
        print(f"Renamed: {file_path.name} -> {new_name}")

print("Done.")
# Out:
# Renamed: gemini_name.ipynb -> gpt_5.4_gemini_name.ipynb
# Renamed: partial_openai_gpt-5.4-2026-03-05_full_focus_epu_first.csv -> gpt_5.4_partial_openai_gpt-5.4-2026-03-05_full_focus_epu_first.csv
# Renamed: partial_openai_gpt-5.4-2026-03-05_full_focus_epu_last.csv -> gpt_5.4_partial_openai_gpt-5.4-2026-03-05_full_focus_epu_last.csv
# Renamed: partial_openai_gpt-5.4-2026-03-05_single_focus.csv -> gpt_5.4_partial_openai_gpt-5.4-2026-03-05_single_focus.csv
# Renamed: partial_openai_gpt-5.4-2026-03-05_single_long_control.csv -> gpt_5.4_partial_openai_gpt-5.4-2026-03-05_single_long_control.csv
# Renamed: pilot_rows_q3_upgraded.csv -> gpt_5.4_pilot_rows_q3_upgraded.csv
# Renamed: q3_article_model_matrix_upgraded.csv -> gpt_5.4_q3_article_model_matrix_upgraded.csv
# Renamed: q3_dependency_table_upgraded.csv -> gpt_5.4_q3_dependency_table_upgraded.csv
# Renamed: q3_manifest_upgraded.csv -> gpt_5.4_q3_manifest_upgraded.csv
# ...

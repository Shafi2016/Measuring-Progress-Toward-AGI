# %%
from pathlib import Path

folder = Path(r"C:\Users\shafiullah.qureshi\OneDrive - Government of Alberta\Documents\unit_work\shafi_docs\Kaggle_agi\Q4_updated\results_q4_attention_upgraded_M4\epu_attention_q4_upgraded_outputs")

for file_path in folder.iterdir():
    if file_path.is_file() and not file_path.name.startswith("deepseek_"):
        new_name = "deepseek_" + file_path.name
        new_path = file_path.with_name(new_name)
        file_path.rename(new_path)
        print(f"Renamed: {file_path.name} -> {new_name}")

print("Done.")
# Out:
# Renamed: gemini_name.ipynb -> deepseek_gemini_name.ipynb
# Renamed: pilot_rows_q4_upgraded.csv -> deepseek_pilot_rows_q4_upgraded.csv
# Renamed: q4_manifest_upgraded.csv -> deepseek_q4_manifest_upgraded.csv
# Renamed: q4_most_harmed_rows_upgraded.csv -> deepseek_q4_most_harmed_rows_upgraded.csv
# Renamed: q4_pairwise_proof_upgraded.csv -> deepseek_q4_pairwise_proof_upgraded.csv
# Renamed: q4_results_long_upgraded.csv -> deepseek_q4_results_long_upgraded.csv
# Renamed: q4_results_wide_checkpoint.csv -> deepseek_q4_results_wide_checkpoint.csv
# Renamed: q4_results_wide_upgraded.csv -> deepseek_q4_results_wide_upgraded.csv
# Renamed: q4_retrieval_table_upgraded.csv -> deepseek_q4_retrieval_table_upgraded.csv
# Renamed: q4_summary_by_disagreement_upgraded.csv -> deepseek_q4_summary_by_disagreement_upgraded.csv
# Renamed: q4_summary_by_gold_epu_upgraded.csv -> deepseek_q4_summary_by_gold_epu_upgraded.csv
# ...
